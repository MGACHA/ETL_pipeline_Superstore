# %% [markdown]
# ### 1. Copy Api Key form Kaggle Account and create the file (save it as .json):

# %% [markdown]
# ``` jason
#
# {
#     "username": "YourUserName",
#     "key": "AGAT_00a000000c0c0c00cb0d0b00000a00aa"
#   }
# ```

# %% [markdown]
# ### 2. Save your kaggle api key file in this location:
# ### C:/Users/username/.kaggle/kaggle.json

# %% [markdown]
# ### 3. In the terminal run :

# %% [markdown]
# ``` bash
# pip install kaggle
# ```

# %% [markdown]
# ### 4. Copy the part of the kaggle URL with username and name of desired dataset
# ### vivek468/superstore-dataset-final
# ### from https://www.kaggle.com/datasets/vivek468/superstore-dataset-final

# %% [markdown]
# ### 5. Paste it into dataset_download_files() and dataset_metadata().
# ### Run the script

# %%
import kaggle
kaggle.api.authenticate()
kaggle.api.dataset_download_files('vivek468/superstore-dataset-final', path='.', unzip=True)

# meta data are optional
kaggle.api.dataset_metadata('vivek468/superstore-dataset-final', path='.')
# Out:
# Dataset URL: https://www.kaggle.com/datasets/vivek468/superstore-dataset-final
# '.\\dataset-metadata.json'
